# %% [markdown]
# <a href="https://colab.research.google.com/github/annegoldriver/machine_learning_python/blob/main/5_loops_%26_list_comprehensions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Loops and List Comprehensions**
#
# * For loop: ONCE for every item in the list
# * Print function : built in vertical output each line
# * end: keyword argument, parameter, socket
# * /n : New line
# * end = ' '

# %%
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
for planet in planets:
    print(planet)
# Out:
# Mercury
# Venus
# Earth
# Mars
# Jupiter
# Saturn
# Uranus
# Neptune

# %%
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
for planet in planets:
    print(planet, end = '---')
# Out:
# Mercury---Venus---Earth---Mars---Jupiter---Saturn---Uranus---Neptune---

# %%
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
for planet in planets:
    print(planet, end = '>>>')
# Out:
# Mercury>>>Venus>>>Earth>>>Mars>>>Jupiter>>>Saturn>>>Uranus>>>Neptune>>>

# %%
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
for planet in planets:
    print(planet, end = '\n\n')
# Out:
# Mercury
#
# Venus
#
# Earth
#
# Mars
#
# Jupiter
#
# Saturn
#
# Uranus
#
# Neptune

# %%
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
for planet in planets:
    print(planet, end = '\n\n\n\n\n')
# Out:
# Mercury
#
#
#
#
# Venus
#
#
#
#
# Earth
#
#
#
#
# Mars
#
#
#
#
# Jupiter
#
#
#
#
# Saturn
#
#
#
#
# Uranus
#
#
#
#
# Neptune

# %%
print("Hello\nAnne")
# Out:
# Hello
# Anne

# %% [markdown]
# **Math Tips: Addition and Multiplications**
#
# 1. Addition: Independence: Law of Stuffs: Counting
# 2. Multiplication: Dependent : Law of Changes: Scailing

# %%
multiplicands = (2, 2, 2, 3, 3, 5)
product = 1
for mult in multiplicands:
    product = product * mult
product
# Out:
# 360
